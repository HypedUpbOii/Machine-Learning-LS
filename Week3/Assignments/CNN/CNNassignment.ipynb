# %% [markdown]
# # **CNN assignment**(Do read the note at the end)

# %% [markdown]
# Description: Here we are going to use CNN to classify images of elephants,tigers,cheetah's and crocodiles. Basically multiclass classificiation using CNN.

# %% [markdown]
# **Q.1** Import all required modules

# %%
#Your code here
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Q.2** Load data using image_dataset_from_directory(https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory)

# %%
data = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/animals",
    labels="inferred",
    label_mode="categorical",
    batch_size=32,
    color_mode="rgb",
    seed = 42,
    image_size=(256,256),
    shuffle=True
)
# Out:
# Found 1658 files belonging to 4 classes.

# %% [markdown]
# *   Since data object is not iterable,we will create a numpy iterator for data.
# *   Then use batch to iterate through our data

# %%
data_iterator=data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %% [markdown]
# Run the below code and batch code 2-3 times to visualise the labels given to different animals.

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(str(batch[1][idx]))

# %% [markdown]
# **Q.3** Map the data such that all pixel values lie between 0 and 1 using the **lambda function**

# %%
data=data.map(lambda x,y: (x/255,y))

# %% [markdown]
# **Q.4** Split the data into train set and test set(and validation set if needed) using **data.take**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-class-take-method/) and **data.skip**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-skip-method/)

# %%
#Your code here
train_ratio = 0.7
val_ratio = 0.1
test_ratio = 0.2

train_size = int(len(data)*train_ratio)
val_size = int(len(data)*val_ratio)
test_size = int(len(data)*test_ratio)

train_data = data.take(train_size)
val_data = data.skip(train_size).take(val_size)
test_data = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# **Creating the model**

# %% [markdown]
# **Q.5** Write code to create CNN model including fully connected layers with softmax as final layer.

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16,(3,3),activation="relu",input_shape=(256,256,3)),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(16,(3,3),activation="relu"),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256,activation="relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128,activation="relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64,activation="relu"),
    tf.keras.layers.Dense(4,activation="softmax")
])

# %% [markdown]
# **Q.6** Compile your model

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# **Q.7** Fit your model with train set and make sure to keep **less epochs**(10-15) as the dataset size is very large.

# %%
model.fit(train_data,epochs=20,validation_data=val_data)
# Out:
# Epoch 1/20
# 36/36 [==============================] - 21s 432ms/step - loss: 1.4063 - accuracy: 0.3064 - val_loss: 1.3634 - val_accuracy: 0.4875
# Epoch 2/20
# 36/36 [==============================] - 17s 461ms/step - loss: 1.3440 - accuracy: 0.3993 - val_loss: 1.2963 - val_accuracy: 0.4313
# Epoch 3/20
# 36/36 [==============================] - 17s 449ms/step - loss: 1.3062 - accuracy: 0.4184 - val_loss: 1.2467 - val_accuracy: 0.4688
# Epoch 4/20
# 36/36 [==============================] - 17s 440ms/step - loss: 1.2250 - accuracy: 0.4653 - val_loss: 1.2195 - val_accuracy: 0.4250
# Epoch 5/20
# 36/36 [==============================] - 18s 474ms/step - loss: 1.1635 - accuracy: 0.5043 - val_loss: 1.0597 - val_accuracy: 0.5562
# Epoch 6/20
# 36/36 [==============================] - 19s 515ms/step - loss: 1.1017 - accuracy: 0.5530 - val_loss: 1.0333 - val_accuracy: 0.5250
# Epoch 7/20
# 36/36 [==============================] - 17s 440ms/step - loss: 1.0474 - accuracy: 0.5816 - val_loss: 0.9559 - val_accuracy: 0.6125
# Epoch 8/20
# 36/36 [==============================] - 17s 457ms/step - loss: 0.9183 - accuracy: 0.6137 - val_loss: 0.7933 - val_accuracy: 0.7000
# Epoch 9/20
# 36/36 [==============================] - 17s 448ms/step - loss: 0.8196 - accuracy: 0.6858 - val_loss: 0.7682 - val_accuracy: 0.7563
# Epoch 10/20
# 36/36 [==============================] - 19s 486ms/step - loss: 0.7064 - accuracy: 0.7535 - val_loss: 0.7316 - val_accuracy: 0.7063
# Epoch 11/20
# 36/36 [==============================] - 16s 429ms/step - loss: 0.5928 - accuracy: 0.7934 - val_loss: 0.5933 - val_accuracy: 0.7688
# Epoch 12/20
# 36/36 [==============================] - 16s 439ms/step - loss: 0.4441 - accuracy: 0.8420 - val_loss: 0.4990 - val_accuracy: 0.8062
# Epoch 13/20
# 36/36 [==============================] - 19s 515ms/step - loss: 0.3444 - accuracy: 0.8845 - val_loss: 0.4418 - val_accuracy: 0.8500
# Epoch 14/20
# 36/36 [==============================] - 18s 477ms/step - loss: 0.3268 - accuracy: 0.8863 - val_loss: 0.5583 - val_accuracy: 0.8000
# Epoch 15/20
# 36/36 [==============================] - 19s 504ms/step - loss: 0.2683 - accuracy: 0.9089 - val_loss: 0.2714 - val_accuracy: 0.8875
# Epoch 16/20
# 36/36 [==============================] - 19s 511ms/step - loss: 0.1627 - accuracy: 0.9410 - val_loss: 0.5771 - val_accuracy: 0.8500
# Epoch 17/20
# 36/36 [==============================] - 18s 475ms/step - loss: 0.1888 - accuracy: 0.9392 - val_loss: 0.2772 - val_accuracy: 0.9000
# Epoch 18/20
# 36/36 [==============================] - 18s 473ms/step - loss: 0.1767 - accuracy: 0.9349 - val_loss: 0.5064 - val_accuracy: 0.8687
# Epoch 19/20
# 36/36 [==============================] - 19s 514ms/step - loss: 0.1322 - accuracy: 0.9583 - val_loss: 0.1950 - val_accuracy: 0.9312
# Epoch 20/20
# 36/36 [==============================] - 17s 441ms/step - loss: 0.1114 - accuracy: 0.9644 - val_loss: 0.3626 - val_accuracy: 0.8938

# %% [markdown]
# **Q.8** Test your code with test set

# %%
loss,accuracy=model.evaluate(test_data)
# Out:
# 10/10 [==============================] - 9s 47ms/step - loss: 0.6563 - accuracy: 0.8875

# %%
# Do not change this code
if accuracy>=0.85:
  print(f"Congratulations, CNN assignment complete!! Your accuracy is {accuracy}")
else:
  print(f"Try again, not enough accuracy! Your accuracy is {accuracy}" )
# Out:
# Congratulations, CNN assignment complete!! Your accuracy is 0.887499988079071

# %% [markdown]
# **Note: 1. Many of you will get very high train accuracy but low test accuracy. This is called overfitting, this can be solved by increasing the train set size. If your getting low accuracy for both train and test, modify your layers in the model.**
#
# **2.Do use T4GPU.Ideally your first epoch will take quite sometime and rest of the epochs will be faster but if all your epochs are taking a lot of time, try starting a new gpu session(open a new gmail account and open colab on that) because your free gpu might have exhausted itself.**
#
# **3.Other than that everything should be fine, happy learning!!**
